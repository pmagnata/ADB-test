# %% [markdown]
# # ADB Technical Profficiency Test - ADO Data Scientist - Magnata, Paolo

# %% [markdown]
# * gdp_pc - GDP Per Capita
# * yrsch - years of schooling

# %%
import pandas as pd
import os

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
path=r'E:\Downloads\ERMR'
file1=r'GDP_per_capita.csv'
file2=r'Years_of_schooling.csv'

# %%
GDP=pd.read_csv(os.path.join(path, file1))
EDUC=pd.read_csv(os.path.join(path, file2))

# %%
GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1062 entries, 0 to 1061
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      1062 non-null   object
#  1   countrycode  1062 non-null   object
#  2   year         1062 non-null   int64
#  3   gdp_pc       1062 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 33.3+ KB

# %% [markdown]
# # GDP EDA
# - country codes and country names are unique and matches are the sames
# - check how many observations there are for each country-country code pair

# %%
GDP.head()
# Out:
#    country countrycode  year  gdp_pc
# 0  Albania         ALB  2002    7922
# 1  Albania         ALB  2003    9633
# 2  Albania         ALB  2004   11497
# 3  Albania         ALB  2005   12481
# 4  Albania         ALB  2006   14703

# %%
GDP.describe()
# Out:
#               year        gdp_pc
# count  1062.000000  1.062000e+03
# mean   2006.000000  3.060566e+05
# std       2.583205  1.034506e+06
# min    2002.000000  2.900000e+02
# 25%    2004.000000  8.990000e+03
# 50%    2006.000000  3.511150e+04
# 75%    2008.000000  1.816198e+05
# max    2010.000000  1.300000e+07

# %%
# No null obesrvations

# %%
GDP.isna().sum()
# Out:
# country        0
# countrycode    0
# year           0
# gdp_pc         0
# dtype: int64

# %%
len(GDP['country'].unique())
# Out:
# 118

# %%
len(GDP['countrycode'].unique())
# Out:
# 118

# %%
GDP_check1=pd.DataFrame(GDP[['country','countrycode']].value_counts()).reset_index().rename(columns=({0:'obs_count'}))
GDP_check1
# Out:
#                                    country countrycode  obs_count
# 0                                  Albania         ALB          9
# 1                                  Namibia         NAM          9
# 2                                 Portugal         PRT          9
# 3                                   Poland         POL          9
# 4                              Philippines         PHL          9
# 5                                     Peru         PER          9
# 6                                 Paraguay         PRY          9
# 7                                   Panama         PAN          9
# 8                                 Pakistan         PAK          9
# 9                                   Norway         NOR          9
# 10                                   Niger         NER          9
# 11                             New Zealand         NZL          9
# 12                             Netherlands         NLD          9
# 13                                   Nepal         NPL          9
# 14                              Mozambique         MOZ          9
# 15                       Republic of Korea         KOR          9
# 16                                 Morocco         MAR          9
# 17                                Mongolia         MNG          9
# 18                                  Mexico         MEX          9
# 19                               Mauritius         MUS          9
# 20                              Mauritania         MRT          9
# 21                                   Malta         MLT          9
# 22                                    Mali         MLI          9
# 23                                Maldives         MDV          9
# 24                                Malaysia         MYS          9
# 25                                  Malawi         MWI          9
# 26                              Luxembourg         LUX          9
# 27                                 Liberia         LBR          9
# 28                                   Qatar         QAT          9
# 29                                 Romania         ROU          9
# 30                               Argentina         ARG          9
# 31                                Thailand         THA          9
# 32                                  Zambia         ZMB          9
# 33                                Viet Nam         VNM          9
# 34                               Venezuela         VEN          9
# 35                                 Uruguay         URY          9
# 36                           United States         USA          9
# 37   United Republic of Tanzania: Mainland         TZA          9
# 38                          United Kingdom         GBR          9
# 39                                  Uganda         UGA          9
# 40                                  Turkey         TUR          9
# 41                                 Tunisia         TUN          9
# 42                     Trinidad and Tobago         TTO          9
# 43                                    Togo         TGO          9
# 44                                  Taiwan         TWN          9
# 45                                  Rwanda         RWA          9
# 46                    Syrian Arab Republic         SYR          9
# 47                             Switzerland         CHE          9
# 48                                  Sweden         SWE          9
# 49                               Swaziland         SWZ          9
# 50                                   Sudan         SDN          9
# 51                               Sri Lanka         LKA          9
# 52                                   Spain         ESP          9
# 53                            South Africa         ZAF          9
# 54                               Singapore         SGP          9
# 55                            Sierra Leone         SLE          9
# 56                                 Senegal         SEN          9
# 57                            Saudi Arabia         SAU          9
# 58                                 Lesotho         LSO          9
# 59        Lao People's Democratic Republic         LAO          9
# 60                                  Kuwait         KWT          9
# 61                                 Burundi         BDI          9
# 62                            Cote dIvoire         CIV          9
# 63                              Costa Rica         CRI          9
# 64                                   Congo         COG          9
# 65                                Colombia         COL          9
# 66                        China: Macao SAR         MAC          9
# 67                    China: Hong Kong SAR         HKG          9
# 68             China, People's Republic of         CHN          9
# 69                                   Chile         CHL          9
# 70                Central African Republic         CAF          9
# 71                                  Canada         CAN          9
# 72                                Cameroon         CMR          9
# 73                                Cambodia         KHM          9
# 74                                Bulgaria         BGR          9
# 75                                   Kenya         KEN          9
# 76                       Brunei Darussalam         BRN          9
# 77                                  Brazil         BRA          9
# 78                                Botswana         BWA          9
# 79                                 Bolivia         BOL          9
# 80                                   Benin         BEN          9
# 81                                  Belize         BLZ          9
# 82                                 Belgium         BEL          9
# 83                                Barbados         BRB          9
# 84                              Bangladesh         BGD          9
# 85                                 Bahrain         BHR          9
# 86                                 Austria         AUT          9
# 87                               Australia         AUS          9
# 88                                  Cyprus         CYP          9
# 89        Democratic Republic of the Congo         COD          9
# 90                                 Denmark         DNK          9
# 91                      Dominican Republic         DOM          9
# 92                                  Jordan         JOR          9
# 93                                   Japan         JPN          9
# 94                                 Jamaica         JAM          9
# 95                                   Italy         ITA          9
# 96                                  Israel         ISR          9
# 97                                 Ireland         IRL          9
# 98                                    Iraq         IRQ          9
# 99              Iran (Islamic Republic of)         IRN          9
# 100                              Indonesia         IDN          9
# 101                                  India         IND          9
# 102                                Iceland         ISL          9
# 103                                Hungary         HUN          9
# 104                               Honduras         HND          9
# 105                              Guatemala         GTM          9
# 106                                 Greece         GRC          9
# 107                                  Ghana         GHA          9
# 108                                Germany         DEU          9
# 109                                 Gambia         GMB          9
# 110                                  Gabon         GAB          9
# 111                                 France         FRA          9
# 112                                Finland         FIN          9
# 113                                   Fiji         FJI          9
# 114                            El Salvador         SLV          9
# 115                                  Egypt         EGY          9
# 116                                Ecuador         ECU          9
# 117                               Zimbabwe         ZWE          9

# %%
GDP_check1.describe()
# Out:
#        obs_count
# count      118.0
# mean         9.0
# std          0.0
# min          9.0
# 25%          9.0
# 50%          9.0
# 75%          9.0
# max          9.0

# %%
GDP_check1['obs_count'].value_counts()
# Out:
# 9    118
# Name: obs_count, dtype: int64

# %%
GDP.head()
# Out:
#    country countrycode  year  gdp_pc
# 0  Albania         ALB  2002    7922
# 1  Albania         ALB  2003    9633
# 2  Albania         ALB  2004   11497
# 3  Albania         ALB  2005   12481
# 4  Albania         ALB  2006   14703

# %%
GDP_check2=pd.DataFrame(GDP.groupby(['country','countrycode'])['gdp_pc'].agg(['min','max','median','mean'])).reset_index()
GDP_check2
# Out:
#                                    country countrycode      min       max  \
# 0                                  Albania         ALB     7922     23572
# 1                                Argentina         ARG    70191    553621
# 2                                Australia         AUS   210741    807484
# 3                                  Austria         AUT    87624    293236
# 4                                  Bahrain         BHR     3549     37399
# 5                               Bangladesh         BGD    68666    255822
# 6                                 Barbados         BRB     2376      6399
# 7                                  Belgium         BEL   113597    349178
# 8                                   Belize         BLZ      322      2065
# 9                                    Benin         BEN     3544     14039
# 10                                 Bolivia         BOL     7460     35976
# 11                                Botswana         BWA      433     29633
# 12                                  Brazil         BRA   286837   1800000
# 13                       Brunei Darussalam         BRN     6197     21700
# 14                                Bulgaria         BGR    24910     91420
# 15                                 Burundi         BDI     2383      6205
# 16                                Cambodia         KHM     5054     33670
# 17                                Cameroon         CMR     8305     44457
# 18                                  Canada         CAN   338974   1200000
# 19                Central African Republic         CAF     1899      3327
# 20                                   Chile         CHL    47417    249925
# 21             China, People's Republic of         CHN   877494  11000000
# 22                    China: Hong Kong SAR         HKG    28852    311260
# 23                        China: Macao SAR         MAC     1229     34784
# 24                                Colombia         COL    86754    379017
# 25                                   Congo         COG     2366     13886
# 26                              Costa Rica         CRI     9443     39982
# 27                            Cote dIvoire         CIV    10641     34494
# 28                                  Cyprus         CYP     2567     18811
# 29        Democratic Republic of the Congo         COD    13742     27875
# 30                                 Denmark         DNK    77719    199107
# 31                      Dominican Republic         DOM    11291     87288
# 32                                 Ecuador         ECU    15198    100465
# 33                                   Egypt         EGY    33101    493029
# 34                             El Salvador         SLV     2020      2897
# 35                                    Fiji         FJI     1602      4358
# 36                                 Finland         FIN    56623    174737
# 37                                  France         FRA   716293   1900000
# 38                                   Gabon         GAB     4252     25785
# 39                                  Gambia         GMB      730      3175
# 40                                 Germany         DEU   945420   2800000
# 41                                   Ghana         GHA    21492     68420
# 42                                  Greece         GRC    75021    271168
# 43                               Guatemala         GTM    14205     56441
# 44                                Honduras         HND     5382     22110
# 45                                 Hungary         HUN    45953    165129
# 46                                 Iceland         ISL     2630     10184
# 47                                   India         IND   668621   4500000
# 48                               Indonesia         IDN   121483   1100000
# 49              Iran (Islamic Republic of)         IRN   126823   1000000
# 50                                    Iraq         IRQ    27578    154808
# 51                                 Ireland         IRL    21281    189033
# 52                                  Israel         ISR    32356    170333
# 53                                   Italy         ITA   557519   1800000
# 54                                 Jamaica         JAM     7185     11372
# 55                                   Japan         JPN  1100000   4000000
# 56                                  Jordan         JOR     4510     35032
# 57                                   Kenya         KEN    14532     68325
# 58                                  Kuwait         KWT    34996    206545
# 59        Lao People's Democratic Republic         LAO     1937     16010
# 60                                 Lesotho         LSO      915      4801
# 61                                 Liberia         LBR      383      2669
# 62                              Luxembourg         LUX     5828     29456
# 63                                  Malawi         MWI     3324     15778
# 64                                Malaysia         MYS    32792    414848
# 65                                Maldives         MDV      290      4691
# 66                                    Mali         MLI     2659     19174
# 67                                   Malta         MLT     1275      8842
# 68                              Mauritania         MRT     2393      9623
# 69                               Mauritius         MUS     3008     16965
# 70                                  Mexico         MEX   356621   1400000
# 71                                Mongolia         MNG     1201     15560
# 72                                 Morocco         MAR    27514    141140
# 73                              Mozambique         MOZ     4466     21373
# 74                                 Namibia         NAM     3863     13838
# 75                                   Nepal         NPL     9126     42340
# 76                             Netherlands         NLD   178380    649609
# 77                             New Zealand         NZL    36964    110832
# 78                                   Niger         NER     5162     11338
# 79                                  Norway         NOR    38190    319285
# 80                                Pakistan         PAK    86540    490891
# 81                                  Panama         PAN     6459     44332
# 82                                Paraguay         PRY     4614     29228
# 83                                    Peru         PER    42142    243118
# 84                             Philippines         PHL    72979   3918320
# 85                                  Poland         POL   145085    665196
# 86                                Portugal         PRT    56976    228087
# 87                                   Qatar         QAT     9812    216556
# 88                       Republic of Korea         KOR    60147   1300000
# 89                                 Romania         ROU    49217    273695
# 90                                  Rwanda         RWA     3591     13012
# 91                            Saudi Arabia         SAU   125807    740332
# 92                                 Senegal         SEN     6382     22588
# 93                            Sierra Leone         SLE     2870      6387
# 94                               Singapore         SGP    12803    255142
# 95                            South Africa         ZAF   153853    501420
# 96                                   Spain         ESP   313496   1300000
# 97                               Sri Lanka         LKA    29680    120544
# 98                                   Sudan         SDN    14454     98730
# 99                               Swaziland         SWZ      526      6153
# 100                                 Sweden         SWE   117867    319461
# 101                            Switzerland         CHE   145175    348260
# 102                   Syrian Arab Republic         SYR    12685    105258
# 103                                 Taiwan         TWN    61908    781381
# 104                               Thailand         THA    72964    644485
# 105                                   Togo         TGO     2989      6782
# 106                    Trinidad and Tobago         TTO    10470     33950
# 107                                Tunisia         TUN    11775     92900
# 108                                 Turkey         TUR   200613   1000000
# 109                                 Uganda         UGA     7886     45040
# 110                         United Kingdom         GBR   711530   1900000
# 111  United Republic of Tanzania: Mainland         TZA    16561     57623
# 112                          United States         USA  4200000  13000000
# 113                                Uruguay         URY    18651     39622
# 114                              Venezuela         VEN   104611    310571
# 115                               Viet Nam         VNM    33414    329279
# 116                                 Zambia         ZMB     7056     27846
# 117                               Zimbabwe         ZWE    10988    103469
#
#         median          mean
# 0      12481.0  1.377967e+04
# 1     153918.0  2.392130e+05
# 2     412095.0  4.599781e+05
# 3     162518.0  1.800044e+05
# 4       7347.0  1.224756e+04
# 5     134837.0  1.411276e+05
# 6       3800.0  4.093111e+03
# 7     206009.0  2.195861e+05
# 8        944.0  1.027667e+03
# 9       6060.0  7.223444e+03
# 10     12845.0  1.773656e+04
# 11      7659.0  1.011722e+04
# 12    784383.0  9.406724e+05
# 13     12229.0  1.355033e+04
# 14     61305.0  5.806933e+04
# 15      3738.0  3.736111e+03
# 16     10602.0  1.334100e+04
# 17     25803.0  2.541333e+04
# 18    733041.0  7.567224e+05
# 19      2652.0  2.601000e+03
# 20     85813.0  1.158193e+05
# 21   2600000.0  3.975277e+06
# 22    135706.0  1.526966e+05
# 23      7128.0  1.050956e+04
# 24    209209.0  2.186808e+05
# 25      4989.0  6.538000e+03
# 26     20094.0  2.296011e+04
# 27     23401.0  2.339900e+04
# 28      9655.0  9.859000e+03
# 29     21155.0  2.091822e+04
# 30    118441.0  1.289294e+05
# 31     28506.0  3.772789e+04
# 32     39868.0  4.782122e+04
# 33    107794.0  1.901421e+05
# 34      2360.0  2.412667e+03
# 35      3663.0  3.256000e+03
# 36    109708.0  1.113787e+05
# 37   1300000.0  1.312629e+06
# 38      9420.0  1.193378e+04
# 39      1354.0  1.610444e+03
# 40   1700000.0  1.793936e+06
# 41     25210.0  3.375656e+04
# 42    141396.0  1.626854e+05
# 43     28492.0  3.220500e+04
# 44     12632.0  1.303667e+04
# 45    110605.0  1.080712e+05
# 46      6497.0  6.405667e+03
# 47   1100000.0  1.668926e+06
# 48    499908.0  5.241911e+05
# 49    263494.0  3.783314e+05
# 50     75214.0  7.662578e+04
# 51     56212.0  8.476689e+04
# 52     83224.0  9.799678e+04
# 53   1200000.0  1.222321e+06
# 54     11124.0  1.018744e+04
# 55   3000000.0  2.788889e+06
# 56     12135.0  1.494989e+04
# 57     39144.0  3.900733e+04
# 58     66425.0  8.831411e+04
# 59      5450.0  6.850222e+03
# 60      2636.0  2.747667e+03
# 61      1967.0  1.840000e+03
# 62     11238.0  1.468789e+04
# 63      6960.0  7.361778e+03
# 64    135362.0  1.820311e+05
# 65      1383.0  1.690444e+03
# 66      5604.0  7.821778e+03
# 67      3901.0  4.604667e+03
# 68      3445.0  4.582556e+03
# 69      9528.0  9.529111e+03
# 70    757314.0  8.482184e+05
# 71      4370.0  5.446667e+03
# 72     87690.0  8.251400e+04
# 73      6500.0  8.850778e+03
# 74      6693.0  7.440111e+03
# 75     18684.0  2.134922e+04
# 76    323394.0  3.766289e+05
# 77     61458.0  6.854467e+04
# 78      6581.0  7.091111e+03
# 79    114147.0  1.486004e+05
# 80    225993.0  2.453408e+05
# 81     14204.0  1.902233e+04
# 82     14383.0  1.501300e+04
# 83     67121.0  1.015172e+05
# 84    206537.0  6.084942e+05
# 85    253954.0  3.340271e+05
# 86    123719.0  1.348827e+05
# 87     14835.0  4.705111e+04
# 88    475028.0  5.820652e+05
# 89    138528.0  1.440156e+05
# 90      5658.0  6.399667e+03
# 91    286675.0  3.637824e+05
# 92     13223.0  1.317167e+04
# 93      3963.0  4.454778e+03
# 94     64129.0  9.083722e+04
# 95    266362.0  2.936127e+05
# 96    582133.0  6.920797e+05
# 97     48180.0  5.875400e+04
# 98     28800.0  3.972022e+04
# 99      3329.0  3.482111e+03
# 100   197713.0  2.058048e+05
# 101   211776.0  2.182599e+05
# 102    18226.0  3.657789e+04
# 103   365074.0  3.917704e+05
# 104   266424.0  3.084458e+05
# 105     4524.0  4.578444e+03
# 106    14291.0  1.768667e+04
# 107    41222.0  4.844078e+04
# 108   487816.0  5.126859e+05
# 109    11940.0  1.858044e+04
# 110  1200000.0  1.269959e+06
# 111    23682.0  2.848800e+04
# 112  7900000.0  8.400000e+06
# 113    24351.0  2.676544e+04
# 114   143332.0  1.707742e+05
# 115    71037.0  1.189969e+05
# 116    10354.0  1.205456e+04
# 117    39994.0  3.931500e+04

# %%
#Observations within the dataset

# %%
GDP_check2[GDP_check2['min']==min(GDP_check2['min'])]
# Out:
#      country countrycode  min   max  median         mean
# 65  Maldives         MDV  290  4691  1383.0  1690.444444

# %%
GDP_check2[GDP_check2['max']==max(GDP_check2['max'])]
# Out:
#            country countrycode      min       max     median       mean
# 112  United States         USA  4200000  13000000  7900000.0  8400000.0

# %% [markdown]
# # Education EDA

# %%
EDUC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      118 non-null    object
#  1   countrycode  118 non-null    object
#  2   yrsch2002    118 non-null    float64
#  3   yrsch2003    118 non-null    float64
#  4   yrsch2004    118 non-null    float64
#  5   yrsch2005    118 non-null    float64
#  6   yrsch2006    118 non-null    float64
#  7   yrsch2007    118 non-null    float64
#  8   yrsch2008    118 non-null    float64
#  9   yrsch2009    118 non-null    float64
#  10  yrsch2010    118 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 10.3+ KB

# %%
# No null observations

# %%
EDUC.isna().sum()
# Out:
# country        0
# countrycode    0
# yrsch2002      0
# yrsch2003      0
# yrsch2004      0
# yrsch2005      0
# yrsch2006      0
# yrsch2007      0
# yrsch2008      0
# yrsch2009      0
# yrsch2010      0
# dtype: int64

# %%
EDUC.head()
# Out:
#      country countrycode  yrsch2002  yrsch2003  yrsch2004  yrsch2005  \
# 0    Albania         ALB       4.63       5.77       6.95       7.93
# 1  Argentina         ARG       6.48       7.03       7.51       8.09
# 2  Australia         AUS      10.11      10.80      11.40      11.43
# 3    Austria         AUT       7.26       7.44       7.60       7.84
# 4    Bahrain         BHR       3.12       4.14       5.04       5.79
#
#    yrsch2006  yrsch2007  yrsch2008  yrsch2009  yrsch2010
# 0       8.61       8.54       9.93      10.24      10.44
# 1       8.67       8.91       9.08       9.57       9.71
# 2      11.44      11.51      11.37      11.71      11.69
# 3       8.26       8.93       9.43       9.89      10.13
# 4       6.73       7.31       7.81       7.43       7.10

# %%
EDUC.describe()
# Out:
#         yrsch2002   yrsch2003   yrsch2004   yrsch2005   yrsch2006   yrsch2007  \
# count  118.000000  118.000000  118.000000  118.000000  118.000000  118.000000
# mean     4.335593    4.879576    5.461780    5.996864    6.534153    7.035678
# std      2.656006    2.745103    2.777353    2.735212    2.791741    2.850706
# min      0.310000    0.460000    0.650000    0.830000    0.950000    0.980000
# 25%      2.147500    2.637500    3.260000    3.950000    4.532500    4.920000
# 50%      4.005000    4.475000    5.195000    5.770000    6.565000    6.960000
# 75%      6.450000    7.027500    7.510000    7.990000    8.702500    9.347500
# max     11.170000   12.030000   12.280000   12.350000   12.550000   12.830000
#
#         yrsch2008   yrsch2009   yrsch2010
# count  118.000000  118.000000  118.000000
# mean     7.486949    7.997458    8.477288
# std      2.878382    2.894785    2.856466
# min      1.130000    1.340000    1.950000
# 25%      5.327500    6.030000    6.367500
# 50%      7.545000    8.100000    8.645000
# 75%      9.927500   10.547500   11.035000
# max     13.100000   13.010000   13.240000

# %% [markdown]
# # converting the educ dataframe into a horizontal dataframe

# %%
EDUC.head()
# Out:
#      country countrycode  yrsch2002  yrsch2003  yrsch2004  yrsch2005  \
# 0    Albania         ALB       4.63       5.77       6.95       7.93
# 1  Argentina         ARG       6.48       7.03       7.51       8.09
# 2  Australia         AUS      10.11      10.80      11.40      11.43
# 3    Austria         AUT       7.26       7.44       7.60       7.84
# 4    Bahrain         BHR       3.12       4.14       5.04       5.79
#
#    yrsch2006  yrsch2007  yrsch2008  yrsch2009  yrsch2010
# 0       8.61       8.54       9.93      10.24      10.44
# 1       8.67       8.91       9.08       9.57       9.71
# 2      11.44      11.51      11.37      11.71      11.69
# 3       8.26       8.93       9.43       9.89      10.13
# 4       6.73       7.31       7.81       7.43       7.10

# %%
EDUC_1=pd.melt(EDUC, id_vars=['country','countrycode'], var_name='year', value_name='yrsch',
               value_vars=['yrsch2002','yrsch2003','yrsch2004','yrsch2005','yrsch2006','yrsch2007','yrsch2008','yrsch2009','yrsch2010'])
EDUC_1['year']=EDUC_1['year'].str.replace('yrsch','')
EDUC_1['year']=EDUC_1['year'].astype('int64')
EDUC_1=EDUC_1.sort_values(['country','year']).reset_index(drop=True)

# %%
EDUC_1.head()
# Out:
#    country countrycode  year  yrsch
# 0  Albania         ALB  2002   4.63
# 1  Albania         ALB  2003   5.77
# 2  Albania         ALB  2004   6.95
# 3  Albania         ALB  2005   7.93
# 4  Albania         ALB  2006   8.61

# %%
len(EDUC_1['country'].unique())
# Out:
# 118

# %%
len(EDUC_1['countrycode'].unique())
# Out:
# 118

# %%
EDUC_1[['country','countrycode']].value_counts()
# Out:
# country                                         countrycode
# Albania                                         ALB            9
# Namibia                                         NAM            9
# Portugal                                        PRT            9
# Poland                                          POL            9
# Philippines                                     PHL            9
# Peru                                            PER            9
# Paraguay                                        PRY            9
# Panama                                          PAN            9
# Pakistan                                        PAK            9
# Norway                                          NOR            9
# Niger                                           NER            9
# New Zealand                                     NZL            9
# Netherlands                                     NLD            9
# Nepal                                           NPL            9
# Mozambique                                      MOZ            9
# Republic of Korea                               KOR            9
# Morocco                                         MAR            9
# Mongolia                                        MNG            9
# Mexico                                          MEX            9
# Mauritius                                       MUS            9
# Mauritania                                      MRT            9
# Malta                                           MLT            9
# Mali                                            MLI            9
# Maldives                                        MDV            9
# Malaysia                                        MYS            9
# Malawi                                          MWI            9
# Luxembourg                                      LUX            9
# Liberia                                         LBR            9
# Qatar                                           QAT            9
# Romania                                         ROU            9
# Argentina                                       ARG            9
# Thailand                                        THA            9
# Zambia                                          ZMB            9
# Vietnam                                         VIE            9
# Venezuela                                       VEN            9
# Uruguay                                         URY            9
# United Republic of Tanzania                     TZA            9
# United Kingdom                                  GBR            9
# Uganda                                          UGA            9
# USA                                             USA            9
# Turkey                                          TUR            9
# Tunisia                                         TUN            9
# Trinidad and Tobago                             TTO            9
# Togo                                            TGO            9
# Taiwan                                          TWN            9
# Rwanda                                          RWA            9
# Syrian Arab Republic                            SYR            9
# Switzerland                                     CHE            9
# Sweden                                          SWE            9
# Swaziland                                       SWZ            9
# Sudan                                           SDN            9
# Sri Lanka                                       LKA            9
# Spain                                           ESP            9
# South Africa                                    ZAF            9
# Singapore                                       SGP            9
# Sierra Leone                                    SLE            9
# Senegal                                         SEN            9
# Saudi Arabia                                    SAU            9
# Lesotho                                         LSO            9
# Lao People's Democratic Republic                LAO            9
# Kuwait                                          KWT            9
# Burundi                                         BDI            9
# Cote dIvoire                                    CIV            9
# Costa Rica                                      CRI            9
# Congo                                           COG            9
# Colombia                                        COL            9
# China, Macao Special Administrative Region      MAC            9
# China, Hong Kong Special Administrative Region  HKG            9
# China                                           CHN            9
# Chile                                           CHL            9
# Central African Republic                        CAF            9
# Canada                                          CAN            9
# Cameroon                                        CMR            9
# Cambodia                                        KHM            9
# Bulgaria                                        BGR            9
# Kenya                                           KEN            9
# Brunei Darussalam                               BRN            9
# Brazil                                          BRA            9
# Botswana                                        BWA            9
# Bolivia                                         BOL            9
# Benin                                           BEN            9
# Belize                                          BLZ            9
# Belgium                                         BEL            9
# Barbados                                        BRB            9
# Bangladesh                                      BGD            9
# Bahrain                                         BHR            9
# Austria                                         AUT            9
# Australia                                       AUS            9
# Cyprus                                          CYP            9
# Democratic Republic of the Congo                COD            9
# Denmark                                         DNK            9
# Dominican Rep.                                  DOM            9
# Jordan                                          JOR            9
# Japan                                           JPN            9
# Jamaica                                         JAM            9
# Italy                                           ITA            9
# Israel                                          ISR            9
# Ireland                                         IRL            9
# Iraq                                            IRQ            9
# Iran (Islamic Republic of)                      IRN            9
# Indonesia                                       IDN            9
# India                                           IND            9
# Iceland                                         ISL            9
# Hungary                                         HUN            9
# Honduras                                        HND            9
# Guatemala                                       GTM            9
# Greece                                          GRC            9
# Ghana                                           GHA            9
# Germany                                         DEU            9
# Gambia                                          GMB            9
# Gabon                                           GAB            9
# France                                          FRA            9
# Finland                                         FIN            9
# Fiji                                            FJI            9
# El Salvador                                     SLV            9
# Egypt                                           EGY            9
# Ecuador                                         ECU            9
# Zimbabwe                                        ZWE            9
# dtype: int64

# %% [markdown]
# # Merging the dataframes

# %%
GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1062 entries, 0 to 1061
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      1062 non-null   object
#  1   countrycode  1062 non-null   object
#  2   year         1062 non-null   int64
#  3   gdp_pc       1062 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 33.3+ KB

# %%
GDP.head()
# Out:
#    country countrycode  year  gdp_pc
# 0  Albania         ALB  2002    7922
# 1  Albania         ALB  2003    9633
# 2  Albania         ALB  2004   11497
# 3  Albania         ALB  2005   12481
# 4  Albania         ALB  2006   14703

# %%
EDUC_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1062 entries, 0 to 1061
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      1062 non-null   object
#  1   countrycode  1062 non-null   object
#  2   year         1062 non-null   int64
#  3   yrsch        1062 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 33.3+ KB

# %%
EDUC_1.head()
# Out:
#    country countrycode  year  yrsch
# 0  Albania         ALB  2002   4.63
# 1  Albania         ALB  2003   5.77
# 2  Albania         ALB  2004   6.95
# 3  Albania         ALB  2005   7.93
# 4  Albania         ALB  2006   8.61

# %% [markdown]
# # Observations:
# - GDP and EDUC have 1062 observations each with 118 unique countries and data for 9 observations for yrsch and GDP per capita across time

# %%
GDP_EDUC=pd.merge(GDP,EDUC_1, on=['country', 'countrycode','year'], how='outer')
GDP_EDUC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1125 entries, 0 to 1124
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      1125 non-null   object
#  1   countrycode  1125 non-null   object
#  2   year         1125 non-null   int64
#  3   gdp_pc       1062 non-null   float64
#  4   yrsch        1062 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 52.7+ KB

# %% [markdown]
# # Notes:
# 1. There are naming differences with the 7 countries:
#
# * "China, People's Republic of"
# * 'China: Hong Kong SAR'
# * 'China: Macao SAR'
# * 'Dominican Republic'
# * 'United Republic of Tanzania: Mainland'
# * 'United States',
# * 'Viet Nam',
# * 'China',
# * 'China, Hong Kong Special Administrative Region',
# * 'China, Macao Special Administrative Region'
# * 'Dominican Rep.',
# * 'USA'
# * 'United Republic of Tanzania'
# * 'Vietnam'

# %%
issues1=GDP_EDUC[(GDP_EDUC['gdp_pc'].isna()) | (GDP_EDUC['yrsch'].isna())]
issues1['country'].unique()
# Out:
# array(["China, People's Republic of", 'China: Hong Kong SAR',
#        'China: Macao SAR', 'Dominican Republic',
#        'United Republic of Tanzania: Mainland', 'United States',
#        'Viet Nam', 'China',
#        'China, Hong Kong Special Administrative Region',
#        'China, Macao Special Administrative Region', 'Dominican Rep.',
#        'USA', 'United Republic of Tanzania', 'Vietnam'], dtype=object)

# %%
# Fixing before proceeding

# %%
GDP['country']=GDP['country'].str.replace("China, People's Republic of", "China")
GDP['country']=GDP['country'].str.replace('China: Hong Kong SAR', 'China, Hong Kong Special Administrative Region')
GDP['country']=GDP['country'].str.replace('China: Macao SAR','China, Macao Special Administrative Region')
GDP['country']=GDP['country'].str.replace('Dominican Republic','Dominican Rep.')
GDP['country']=GDP['country'].str.replace('United Republic of Tanzania: Mainland','United Republic of Tanzania')
GDP['country']=GDP['country'].str.replace('United States','USA')
GDP['country']=GDP['country'].str.replace('Viet Nam', 'Vietnam')

# %%
# not merging on country code as VIETNAM country code is different

# %%
GDP_EDUC1=pd.merge(GDP,EDUC_1, on=['country', 'year'], how='outer')
GDP_EDUC1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1062 entries, 0 to 1061
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        1062 non-null   object
#  1   countrycode_x  1062 non-null   object
#  2   year           1062 non-null   int64
#  3   gdp_pc         1062 non-null   int64
#  4   countrycode_y  1062 non-null   object
#  5   yrsch          1062 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 58.1+ KB

# %%
GDP_EDUC1.head()
# Out:
#    country countrycode_x  year  gdp_pc countrycode_y  yrsch
# 0  Albania           ALB  2002    7922           ALB   4.63
# 1  Albania           ALB  2003    9633           ALB   5.77
# 2  Albania           ALB  2004   11497           ALB   6.95
# 3  Albania           ALB  2005   12481           ALB   7.93
# 4  Albania           ALB  2006   14703           ALB   8.61

# %%
# Creating the Growth Rate for GDP Per Capita

# %%
groups=GDP_EDUC1.sort_values('year').groupby(['country'])
GDP_EDUC1['gdp_pc_perc']=(groups['gdp_pc'].pct_change().mul(100).round(2)
                    .where(groups['year'].diff()==1))
GDP_EDUC1.head()
# Out:
#    country countrycode_x  year  gdp_pc countrycode_y  yrsch  gdp_pc_perc
# 0  Albania           ALB  2002    7922           ALB   4.63          NaN
# 1  Albania           ALB  2003    9633           ALB   5.77        21.60
# 2  Albania           ALB  2004   11497           ALB   6.95        19.35
# 3  Albania           ALB  2005   12481           ALB   7.93         8.56
# 4  Albania           ALB  2006   14703           ALB   8.61        17.80

# %%
# looped graphs for 4 countries

# %%
GDP_COUNTRY_GRAPH=['Philippines','Thailand','Indonesia','India']

# %%
output_path='test'

# %%
GDP_EDUC1[GDP_EDUC1['country']=='Philippines']
# Out:
#          country countrycode_x  year   gdp_pc countrycode_y  yrsch  \
# 756  Philippines           PHL  2002    72979           PHL   4.83
# 757  Philippines           PHL  2003   102914           PHL   5.56
# 758  Philippines           PHL  2004   134363           PHL   6.26
# 759  Philippines           PHL  2005   133333           PHL   6.64
# 760  Philippines           PHL  2006   206537           PHL   7.15
# 761  Philippines           PHL  2007   290955           PHL   7.59
# 762  Philippines           PHL  2008   292452           PHL   7.96
# 763  Philippines           PHL  2009   324595           PHL   8.27
# 764  Philippines           PHL  2010  3918320           PHL   8.65
#
#      gdp_pc_perc
# 756          NaN
# 757        41.02
# 758        30.56
# 759        -0.77
# 760        54.90
# 761        40.87
# 762         0.51
# 763        10.99
# 764      1107.14

# %% [markdown]
# # Observations
# 1. Philippines had a stagnant GDP Per Capita growth rate until 2010 where it experienced a spike of up to 1100% and can be considered as an outlier
# 2. Thailand and Indonesi experienced a striking drop in GDP Per Capita growth rate in 2008, which is consequentlyy when th 2008 financial crisis ocurred
# 3. India experienced a spike in its GDP Per Capita growth rate in 2006 and was able to subsequently experience higher growth  rates in 2009 and 2010 despite setbacks in 2007.

# %%
import matplotlib.pyplot as plt
for n in GDP_COUNTRY_GRAPH:
    df=GDP_EDUC1[GDP_EDUC1['country']==n]
    plt.plot('year', 'gdp_pc_perc', data=df)
    test = n  + ' - GDP Per Capita Growth Rates'
    plt.title(test)
    #plt.savefig(os.path.join(output_path,'GDP_PC_PERC',str(n)))
    plt.show()

# %%
# Scatterplot

# %%
GDP_EDUC1.head()
# Out:
#    country countrycode_x  year  gdp_pc countrycode_y  yrsch  gdp_pc_perc
# 0  Albania           ALB  2002    7922           ALB   4.63          NaN
# 1  Albania           ALB  2003    9633           ALB   5.77        21.60
# 2  Albania           ALB  2004   11497           ALB   6.95        19.35
# 3  Albania           ALB  2005   12481           ALB   7.93         8.56
# 4  Albania           ALB  2006   14703           ALB   8.61        17.80

# %%
import numpy as np
import seaborn as sns

# %%
f = plt.figure(figsize=(15,10))
sns.regplot(y='gdp_pc', x='yrsch', data=GDP_EDUC1, color='black')
sns.scatterplot(y='gdp_pc', x='yrsch', data=GDP_EDUC1, color='red')
plt.xlabel('Years of Schooling')
plt.ylabel('GDP Per Capita')
plt.title('GDP Per Capita vs. Years of Schooling')
# plt.savefig(os.path.join('output_path','GDP_PC_vs_YRSCH.png'))
plt.show()

# %%
# summary table requirements

GDP_sum=pd.DataFrame(GDP_EDUC1.groupby(['country'])['gdp_pc'].agg(['count','min','max','median','mean'])).reset_index()
GDP_sum.head()
# Out:
#      country  count     min     max    median           mean
# 0    Albania      9    7922   23572   12481.0   13779.666667
# 1  Argentina      9   70191  553621  153918.0  239213.000000
# 2  Australia      9  210741  807484  412095.0  459978.111111
# 3    Austria      9   87624  293236  162518.0  180004.444444
# 4    Bahrain      9    3549   37399    7347.0   12247.555556

# %%
# summary table requirements

EDUC_sum=pd.DataFrame(GDP_EDUC1.groupby(['country'])['yrsch'].agg(['count','min','max','median','mean'])).reset_index()
EDUC_sum.head()
# Out:
#      country  count    min    max  median       mean
# 0    Albania      9   4.63  10.44    8.54   8.115556
# 1  Argentina      9   6.48   9.71    8.67   8.338889
# 2  Australia      9  10.11  11.71   11.43  11.273333
# 3    Austria      9   7.26  10.13    8.26   8.531111
# 4    Bahrain      9   3.12   7.81    6.73   6.052222

# %%
# sorry didn't have enough time for the FE

# %% [markdown]
# # PANEL OLS

# %%
from linearmodels import PanelOLS
import statsmodels.api as sm

# %%
GDP_EDUC2=GDP_EDUC1.set_index(['country','year'])
GDP_EDUC2.drop(columns=['countrycode_x','countrycode_y'], inplace=True)
GDP_EDUC2['ln_gdp_pc']=np.log(GDP_EDUC2['gdp_pc'])

# %%
# Pooled OLS

# %%
# adding a column of ones for the constant
exog = sm.add_constant(GDP_EDUC2['yrsch'])

pooled_ols = PanelOLS(GDP_EDUC2['ln_gdp_pc'], exog, entity_effects=False, time_effects=False)
result_pooled=pooled_ols.fit()
display(result_pooled.summary)
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              ln_gdp_pc   R-squared:                        0.2481
# Estimator:                   PanelOLS   R-squared (Between):              0.2099
# No. Observations:                1062   R-squared (Within):               0.6882
# Date:                Thu, Jun 30 2022   R-squared (Overall):              0.2481
# Time:                        13:20:10   Log-likelihood                   -2103.2
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      349.74
# Entities:                         118   P-value                           0.0000
# Avg Obs:                       9.0000   Distribution:                  F(1,1060)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             349.74
#                                         P-value                           0.0000
# Time periods:                       9   Distribution:                  F(1,1060)
# Avg Obs:                       118.00
# Min Obs:                       118.00
# Max Obs:                       118.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          8.5346     0.1249     68.339     0.0000      8.2896      8.7797
# yrsch          0.3258     0.0174     18.701     0.0000      0.2916      0.3600
# ==============================================================================
#
#
# """

# %%
# two-way fixed effects

# %%
two_way_fe = PanelOLS(GDP_EDUC2['ln_gdp_pc'], exog, entity_effects=True, time_effects=True)
result_fe=two_way_fe.fit()
display(result_fe)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              ln_gdp_pc   R-squared:                        0.0424
# Estimator:                   PanelOLS   R-squared (Between):              0.1128
# No. Observations:                1062   R-squared (Within):               0.3692
# Date:                Thu, Jun 30 2022   R-squared (Overall):              0.1332
# Time:                        14:42:36   Log-likelihood                   -166.78
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      41.385
# Entities:                         118   P-value                           0.0000
# Avg Obs:                       9.0000   Distribution:                   F(1,935)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             41.385
#                                         P-value                           0.0000
# Time periods:                       9   Distribution:                   F(1,935)
# Avg Obs:                       118.00
# Min Obs:                       118.00
# Max Obs:                       118.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          9.9684     0.1051     94.848     0.0000      9.7621      10.175
# yrsch          0.1041     0.0162     6.4332     0.0000      0.0724      0.1359
# ==============================================================================
#
# F-test for Poolability: 279.38
# P-value: 0.0000
# Distribution: F(125,935)
#
# Included effects: Entity, Time
# PanelEffectsResults, id: 0x22d3435a430

# %% [markdown]
# # Interpretation
# 1. The coefficient of yrsch is 0.1041 in the two-way fixed effects model. It's significant with a p-value of less than 0.001. This indicates that 1 additional year in schooling results to a 10.97% increase in GDP per capita.
# 2. Moreover, the goodness of fit (i.e. R^2) inidicates that this two-way fixed effects model measures only 4.2% of the variation in GDP Per Capita and is conservative compared to the pooled OLS which explains 24.8% of the variation.
